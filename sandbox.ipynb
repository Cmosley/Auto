# %% [markdown]
# # Capstone Project

# %% [markdown]
# Store numbers
# 10, 112, 201,202,204,205,206,207

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/all stores/LubeSoft Reports-Sales-Daily Sales by Store.csv')

# %% [markdown]
# ### Sales data by store for 2018

# %%
df
# Out:
#      Store Number        Date   Gross Amount     Net Amount  \
# 0              10  01/01/2018        $453.26        $453.26
# 1             NaN  01/02/2018      $1,331.58      $1,331.58
# 2             NaN  01/03/2018      $1,574.35      $1,574.35
# 3             NaN  01/04/2018      $1,907.33      $1,907.33
# 4             NaN  01/05/2018      $2,748.98      $2,748.98
# ...           ...         ...            ...            ...
# 2674          NaN  12/28/2018      $6,210.68      $6,195.68
# 2675          NaN  12/29/2018      $5,340.38      $5,300.38
# 2676          NaN  12/31/2018      $4,832.62      $4,805.12
# 2677          207         NaN  $1,318,346.46  $1,304,279.70
# 2678        Total         NaN  $8,843,070.75  $8,651,614.73
#
#      Store Ticket Net Amount Warranty Amount  Average Included Bay Time  \
# 0                    $453.26           $0.00                       21.1
# 1                  $1,331.58           $0.00                       13.8
# ...

# %%
# looks like it totals the sales of each store at the end of the year
# possibly need to drop these rows out of df
df.iloc[2677]
# Out:
# Store Number                           207
# Date                                   NaN
# Gross Amount                 $1,318,346.46
# Net Amount                   $1,304,279.70
# Store Ticket Net Amount      $1,295,913.06
# Warranty Amount                      $0.00
# Average Included Bay Time              NaN
# Store Ticket Count                  21,767
# Store Ticket Average Net            $59.54
# Promotion Amount                $14,066.76
# Name: 2677, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2679 entries, 0 to 2678
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store Number               17 non-null     object
#  1   Date                       2670 non-null   object
#  2   Gross Amount               2679 non-null   object
#  3   Net Amount                 2679 non-null   object
#  4   Store Ticket Net Amount    2679 non-null   object
#  5   Warranty Amount            2679 non-null   object
#  6   Average Included Bay Time  2670 non-null   float64
#  7   Store Ticket Count         2679 non-null   object
#  8   Store Ticket Average Net   2679 non-null   object
#  9   Promotion Amount           2679 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 209.4+ KB

# %% [markdown]
# # store 10

# %%
df10 = df[:362].fillna(value=10)

# %%
df10['Store Number'].value_counts()
# Out:
# 10    361
# 10      1
# Name: Store Number, dtype: int64

# %% [markdown]
# # store 112

# %%
df112 = df[363:725]

# %%
df112 = df112.fillna(value=112, inplace=True)

# %%
df112 = df[363:725].fillna(112)

# %%
df112
# Out:
#     Store Number        Date Gross Amount Net Amount Store Ticket Net Amount  \
# 363          112  01/01/2018      $739.09    $739.09                 $739.09
# 364          112  01/02/2018    $2,507.31  $2,507.31               $2,507.31
# 365          112  01/03/2018    $2,705.21  $2,705.21               $2,705.21
# 366          112  01/04/2018    $3,325.58  $3,325.58               $3,325.58
# 367          112  01/05/2018    $2,864.77  $2,864.77               $2,864.77
# ..           ...         ...          ...        ...                     ...
# 720          112  12/27/2018    $2,164.48  $2,164.48               $2,164.48
# 721          112  12/28/2018    $2,780.12  $2,780.12               $2,780.12
# 722          112  12/29/2018    $2,803.81  $2,803.81               $2,803.81
# 723          112  12/30/2018    $1,126.48  $1,126.48               $1,126.48
# 724          112  12/31/2018    $2,122.59  $2,122.59               $2,122.59
#
# ...

# %%
df112.columns
# Out:
# Index(['Store Number', 'Date', 'Gross Amount', 'Net Amount',
#        'Store Ticket Net Amount', 'Warranty Amount',
#        'Average Included Bay Time', 'Store Ticket Count',
#        'Store Ticket Average Net', 'Promotion Amount'],
#       dtype='object')

# %%
df112['Store Number'].value_counts()
# Out:
# 112    361
# 112      1
# Name: Store Number, dtype: int64

# %% [markdown]
# # Store 207

# %%
df207_2019 = pd.read_csv('./data/207/2019/Daily_Sales_2019.csv')

# %%
df207_2019
# Out:
#     Store Number        Date   Gross Amount     Net Amount  \
# 0            207  01/02/2019      $3,515.97      $3,505.97
# 1            NaN  01/03/2019      $5,758.93      $5,708.43
# 2            NaN  01/04/2019      $5,416.13      $5,386.13
# 3            NaN  01/05/2019      $4,815.44      $4,805.44
# 4            NaN  01/07/2019      $4,782.72      $4,757.72
# ..           ...         ...            ...            ...
# 304          NaN  12/28/2019      $3,832.58      $3,777.08
# 305          NaN  12/30/2019      $7,538.09      $7,422.09
# 306          NaN  12/31/2019      $6,802.28      $6,686.78
# 307          207         NaN  $1,420,439.64  $1,411,294.01
# 308        Total         NaN  $1,420,439.64  $1,411,294.01
#
#     Store Ticket Net Amount Warranty Amount  Average Included Bay Time  \
# 0                 $3,449.01           $0.00                        0.0
# 1                 $5,694.43           $0.00                        0.0
# ...

# %%
df207_2019['Store Number'].fillna(207, inplace=True)

# %%
df207_2019
# Out:
#     Store Number        Date   Gross Amount     Net Amount  \
# 0            207  01/02/2019      $3,515.97      $3,505.97
# 1            207  01/03/2019      $5,758.93      $5,708.43
# 2            207  01/04/2019      $5,416.13      $5,386.13
# 3            207  01/05/2019      $4,815.44      $4,805.44
# 4            207  01/07/2019      $4,782.72      $4,757.72
# ..           ...         ...            ...            ...
# 304          207  12/28/2019      $3,832.58      $3,777.08
# 305          207  12/30/2019      $7,538.09      $7,422.09
# 306          207  12/31/2019      $6,802.28      $6,686.78
# 307          207         NaN  $1,420,439.64  $1,411,294.01
# 308        Total         NaN  $1,420,439.64  $1,411,294.01
#
#     Store Ticket Net Amount Warranty Amount  Average Included Bay Time  \
# 0                 $3,449.01           $0.00                        0.0
# 1                 $5,694.43           $0.00                        0.0
# ...

# %%
df207_2019.columns
# Out:
# Index(['Store Number', 'Date', 'Gross Amount', 'Net Amount',
#        'Store Ticket Net Amount', 'Warranty Amount',
#        'Average Included Bay Time', 'Store Ticket Count',
#        'Store Ticket Average Net', 'Promotion Amount'],
#       dtype='object')

# %%
df207_2019.drop(columns=('Average Included Bay Time'))
# Out:
#     Store Number        Date   Gross Amount     Net Amount  \
# 0            207  01/02/2019      $3,515.97      $3,505.97
# 1            207  01/03/2019      $5,758.93      $5,708.43
# 2            207  01/04/2019      $5,416.13      $5,386.13
# 3            207  01/05/2019      $4,815.44      $4,805.44
# 4            207  01/07/2019      $4,782.72      $4,757.72
# ..           ...         ...            ...            ...
# 304          207  12/28/2019      $3,832.58      $3,777.08
# 305          207  12/30/2019      $7,538.09      $7,422.09
# 306          207  12/31/2019      $6,802.28      $6,686.78
# 307          207         NaN  $1,420,439.64  $1,411,294.01
# 308        Total         NaN  $1,420,439.64  $1,411,294.01
#
#     Store Ticket Net Amount Warranty Amount Store Ticket Count  \
# 0                 $3,449.01           $0.00                 63
# 1                 $5,694.43           $0.00                 88
# 2                 $5,358.13           $0.00                106
# ...

# %%
df207_2019
# Out:
#     Store Number        Date   Gross Amount     Net Amount  \
# 0            207  01/02/2019      $3,515.97      $3,505.97
# 1            207  01/03/2019      $5,758.93      $5,708.43
# 2            207  01/04/2019      $5,416.13      $5,386.13
# 3            207  01/05/2019      $4,815.44      $4,805.44
# 4            207  01/07/2019      $4,782.72      $4,757.72
# ..           ...         ...            ...            ...
# 304          207  12/28/2019      $3,832.58      $3,777.08
# 305          207  12/30/2019      $7,538.09      $7,422.09
# 306          207  12/31/2019      $6,802.28      $6,686.78
# 307          207         NaN  $1,420,439.64  $1,411,294.01
# 308        Total         NaN  $1,420,439.64  $1,411,294.01
#
#     Store Ticket Net Amount Warranty Amount  Average Included Bay Time  \
# 0                 $3,449.01           $0.00                        0.0
# 1                 $5,694.43           $0.00                        0.0
# ...
